# %% [markdown]
# ## 웹 크롤링 라이브러리 사용하기

# %% [markdown]
# ### 페이지의 URL 정보 추출하기

# %% [markdown]
# requests.get() 함수로 URL의 HTML 문서를 가져온 뒤, 이를 BeautifulSoup() 클래스의 soup 객체로 변환
#
# find(), find_all() 함수를 사용 - 특정 HTML 태그 or 특정 HTML 클래스를 가진 데이터를 가지고 오기
#
# HTML 구조에 기반하여 table -> tbody -> tr -> td -> a 태그 순의 HTML 계층 구조를 좁혀나가는 과정
#
# 목표 태그에 도달했을 때, get(href) 함수로 태그의 속성 정보 추출 / get() 함수 = 해당 태그가 가지고 있는 특정한 속성 추출

# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
# 크롤링할 사이트 주소 정의
source_url = "https://namu.wiki/RecentChanges"

# %%
# 사이트의 html 구조에 기반하여 크롤링 수행
req = requests.get(source_url)
html = req.content
soup = BeautifulSoup(html, 'lxml')
contents_table = soup.find(name="table")
table_body = contents_table.find(name="tbody")
table_rows = table_body.find_all(name="tr")

# %%
# a태그의 href 속성을 리스트로 추출하여, 크롤링 할 페이지 리스트 생성
page_url_base = "https://namu.wiki"
page_urls = []
for index in range(0, len(table_rows)):
    first_td = table_rows[index].find_all('td')[0]
    td_url = first_td.find_all('a')
    if len(td_url) > 0:
        page_url = page_url_base + td_url[0].get('href')
        page_urls.append(page_url)

# %%
# 중복 url 제거
page_urls = list(set(page_urls))
for page in page_urls[:5]:
    print(page)
# Out:
# https://namu.wiki/w/%EC%9A%B0%EC%A3%BC%ED%95%98%EB%A7%88
# https://namu.wiki/w/%EC%A1%B0%EC%BB%A4(%EA%B4%B4%EB%8F%84%20%EC%A1%B0%EC%BB%A4)
# https://namu.wiki/w/%EB%82%B4%EB%A5%99%EC%A7%80%EC%97%AD
# https://namu.wiki/w/%EC%9B%94%EB%93%9C%20%EC%98%A4%EB%B8%8C%20%ED%83%B1%ED%81%AC/%EB%A7%B5
# https://namu.wiki/w/%EC%A0%95%EB%8F%99%EC%9B%90/%EC%95%84%EB%82%B4%EC%9D%98%20%EB%A7%9B

# %% [markdown]
# ## 텍스트 정보 수집하기

# %% [markdown]
# ### URL 페이지 정보를 기반으로 크롤링하기

# %% [markdown]
# 최근 변경된 문서 중 한 페이지의 텍스트 정보 크롤링
#
# get() 함수 -> text() 함수 사용 / 태그의 텍스트 정보만을 추출

# %%
# 최근 변경된 문서 하나 크롤링
req = requests.get(page_urls[0])
html = req.content
soup = BeautifulSoup(html, 'lxml')
title = soup.find(name = "h1", attrs={"class":"title"})
category = soup.find(name = "div", attrs={"class":"wiki-category"})
content_clearfix = soup.find(name = "div", attrs={"class":"wiki-content clearfix"})

print(title.text)
print(category.text)
print(content_clearfix.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-f7eefefdcea6> in <module>
#       7 content_clearfix = soup.find(name = "div", attrs={"class":"wiki-content clearfix"})
#       8
# ----> 9 print(title.text)
#      10 print(category.text)
#      11 print(content_clearfix.text)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
req = requests.get(page_urls[0])
html = req.content
soup = BeautifulSoup(html, 'lxml')
contents_table = soup.find(name="article")
title = contents_table.find_all('h1')[0]
category = contents_table.find_all('ul')[0]
content_paragraphs = contents_table.find_all(name="div", attrs={"class":"wiki-paragraph"})
content_corpus_list = []

for paragraphs in content_paragraphs:
    content_corpus_list.append(paragraphs.text)
content_corpus = "".join(content_corpus_list)

print(title.text)
print("\n")
print(category.text)
print("\n")
print(content_corpus)
# Out:
# 우주하마
#
#
# 유튜버/ㅇ트위치 스트리머/ㅇ나무위키 인터넷 방송인 프로젝트
#
#
# 이 문서는이 문단은 토론을 통해 6.4문단에 우주하마 어몽어스에 대한 비판을 자유롭게 서술하기(으)로 합의되었습니다. 합의된 부분을 토론 없이 수정할 시 제재될 수 있습니다. 아래 토론들로 합의된 편집방침이 적용됩니다. 합의된 부분을 토론 없이 수정할 시 제재될 수 있습니다. [ 내용 펼치기 · 접기 ]토론 - 6.4문단에 우주하마 어몽어스에 대한 비판을 자유롭게 서술하기토론 - 4.4문단에 6.4문단을 언급하고 링크로 연결하기토론 - 합의사항3토론 - 합의사항4토론 - 합의사항5토론 - 합의사항6토론 - 합의사항7토론 - 합의사항8토론 - 합의사항9토론 - 합의사항10토론 - 합의사항11토론 - 합의사항12토론 - 합의사항13토론 - 합의사항14토론 - 합의사항15토론 - 합의사항16토론 - 합의사항17토론 - 합의사항18토론 - 합의사항19토론 - 합의사항20토론 - 합의사항21토론 - 합의사항22토론 - 합의사항23토론 - 합의사항24토론 - 합의사항25토론 - 합의사항26토론 - 합의사항27토론 - 합의사항28토론 - 합의사항29토론 - 합의사항30토론 - 합의사항31토론 - 합의사항32토론 - 합의사항33토론 - 합의사항34토론 - 합의사항35토론 - 합의사항36토론 - 합의사항37토론 - 합의사항38토론 - 합의사항39토론 - 합의사항40토론 - 합의사항41토론 - 합의사항42토론 - 합의사항43토론 - 합의사항44토론 - 합의사항45토론 - 합의사항46토론 - 합의사항47토론 - 합의사항48토론 - 합의사항49토론 - 합의사항50토론 - 6.4문단에 우주하마 어몽어스에 대한 비판을 자유롭게 서술하기토론 - 4.4문단에 6.4문단을 언급하고 링크로 연결하기토론 - 합의사항3토론 - 합의사항4토론 - 합의사항5토론 - 합의사항6토론 - 합의사항7토론 - 합의사항8토론 - 합의사항9토론 - 합의사항10토론 - 합의사항11토론 - 합의사항12토론 - 합의사항13토론 - 합의사항14토론 - 합의사항15토론 - 합의사항16토론 - 합의사항17토론 - 합의사항18토론 - 합의사항19토론 - 합의사항20토론 - 합의사항21토론 - 합의사항22토론 - 합의사항23토론 - 합의사항24토론 - 합의사항25토론 - 합의사항26토론 - 합의사항27토론 - 합의사항28토론 - 합의사항29토론 - 합의사항30토론 - 합의사항31토론 - 합의사항32토론 - 합의사항33토론 - 합의사항34토론 - 합의사항35토론 - 합의사항36토론 - 합의사항37토론 - 합의사항38토론 - 합의사항39토론 - 합의사항40토론 - 합의사항41토론 - 합의사항42토론 - 합의사항43토론 - 합의사항44토론 - 합의사항45토론 - 합의사항46토론 - 합의사항47토론 - 합의사항48토론 - 합의사항49토론 - 합의사항50생일6월 7일혈액형B형[1]거주지서울특별시[2]병역  육군 제2보병사단 병장 만기전역[3][4] 직업스트리머, 유튜버, [5]구독자1,070,000명[6]총 조회수362,326,626회[7]방송장르게임소속없음키187cm[8]몸무게77kg가족부모님, 여동생발사이즈275mm[9]링크      [10]1. 개요2. 프로필3. 방송3.1. 채팅창 은어 및 유행어4. 방송 컨텐츠4.1. 어몽어스4.2. 병맛 혹은 킬링 타임4.3. 노래방5. 이전 컨텐츠5.1. 배틀그라운드5.1.1. 성적 및 유형5.1.2. 그 밖의 것5.2. 오버워치5.3. 리그 오브 레전드5.4. Getting Over It with Bennett Foddy5.5. 포트나이트5.6. DEAD BY DAYLIGHT5.7. 렐름로얄6. 논란 및 비판6.1. 오버워치 핵 옹호 논란6.2. 미흡한 채팅 관리6.3. 비매너 보이스 논란6.4. 어몽어스 트롤링과 팬 관리 논란6.4.1. 구체적인 피해 사항6.4.2. 해결 방법6.5. 어몽어스 '분신사바' 전략 논란7. 기타게임[11] 스트리머이자 유튜버. 2016년 11월 30일에 방송을 시작하여 2020년 10월 4일 현재 유튜브 구독자 108만 명과 트위치 팔로워 24.3만명에 이르고 있다.생방송은 유튜브와 트위치에서 동시 송출 하며, 공식적인 방송 시간은 랜덤이다.주로 저녁을 먹은 후 오후 8시 반에서 10시 반 사이에 시작한다고 언급한 바 있다.[7] 수요일과 토요일은 정기 휴방이다.[13]현재 얼굴에 대해서 알려진 정보로는 안경[14]을 끼지 않았다는 것과 무쌍에 긴 눈이라는 것이다.[15] 9.18 생방송에 쟁반에 비친 그림자와 떨어진 머리카락을 보니 반곱슬 내지는 곱슬머리일 수도 있다.이름[16]과 나이는 공개하지 않았다. 목소리가 좋다는 의견이 많다. 대졸이며 운전병 출신의 군필자이다.부르는 노래들을 들어 보면 30대 초 중반까지도 가능성이 있다. 다만 반말미션 수행 중 본인이 34살에게 반말을 어떻게 하느냐며 반박한 것으로 보아 34살에게 반말을 할 수 없을 정도의 나이로 추정된다. 반말미션 광탈2020년 9월1 0일 어몽어스 방송 중 할아버지 컨셉을 하며 100세까지 사는 것이 꿈이라고 하였는데 100세까지 1년남았다고 하였고 70년째 탑골공원에서 돗자리깔고 운세를 봐주었다 라는 말을 참고하면 99세-70년 현재 29살로 추측된다는 썰이 있다.발사이즈는 275이고 손은 키보드의 F1부터 쟀을 때 F11까지 닿는다며, 키에 비해 크지 않다고 한다. 컴퓨터공학과 출신이다. 그러면 게임을 만들지 왜 게임을 하고 있지 서울토박이. 어렸을 때초등학생 별명이 전기뱀장어였다고 밝혔는데 이유가 단순히 성이 ‘전’씨여서 그랬다고 하며 돌잡이 때엔 실과 돈을 잡았다고 한다.방송은 2016년 11월 30일에 시작했다.[17]시청자와 소통 중, 자신이 얼굴을 공개하지 않는 이유를 베스트셀러에 비유해 설명한 적이 있다. '사람들은 책의 내용이 궁금해서 그걸 산다. 이미 책 내용을 다 알면 돈 주고 읽을 필요가 없다. 종종 같은 내용의 영화를 원작의 책보다 덜 찾는 것도 궁금증과 상상력보다 시각적 자극의 영향력이 더 작기 때문이다.'라고 설명했다. 그의 깊은 생각과 입담이 어우러진 부분이라며 채팅 반응이 뜨거웠다.[18]방송에서 나온 웃긴, 멋있는 장면들을 유튜브에 편집하여 올린다. 영상 편집과 썸네일 제작은 편집자가 한다. 2019년 2월 3일에 업로드 된 '사녹 치킨 강의 100% 합격률 보장!!!' 영상부터 자막이 추가되었고, 당일 방송 중에 함께 작업하는 편집자를 구했음을 알렸다.2019년 10월 7일, '콜 오브 듀티: 모바일'로 첫 모바일 방송을 하였다. 모바일 방송을 위해 아이패드 미니 5를 구매했다고 한다. 동시에 처음으로 캠 방송을 진행했는데 짧게 손만 보여준 방송이었지만 평소 철저한 신비주의였기 때문에 많은 시청자가 신기하다는 반응을 보였다.[19]방송에서 한 번 파맛첵스를 먹고 토했다.하마링: 하마 방송 애청자를 칭했으나 본인은 인정하지 않은 비공식 명칭임. 애칭은 때가 되면 짓겠다고 그냥 하마시청자하청자라고 하길 원한다. 시청자들이 하마링이라고 하면 단호하게 쓰지 말아줄 것을 권고한다. 우주하마는 이름을 지을 때 굉장히 신중하다고 한다. 그리고 자신은 귀엽지 않은데, '하마링'이라는 애칭은 너무 귀엽다며 정하게 되면 알려준다고 말했다.하마똥: 2018년 7월 3일, 하마똥 도네영상을 보면서 하마똥이 흩어지는 모습이 꼭 시청자 같고 귀엽다며 좋아하다가 시청자 애칭으로 '하마똥'을 채택했다. 방제를 '우주하마와 하마똥들'로 바꿈으로써 공지(?)했다.독사새끼(들): 2019년 4월 15일, 생방송중 ‘집 한채+시체 1회 파밍으로 우승하기’ 미션 진행중에 파밍한 아이템을 반납하는 상황이 생겼고, 이때 우주하마는 5탄 84발을 덜 반납하게 되었다. 이를 놓치지 않은 시청자들이 5탄 84발을 반납해야 한다고 달려들자, 한 시청자가 ‘독사새끼들’ 이라는 채팅을 쳤는데 이 채팅을 본 우주하마는 물론이고 시청자들까지 아주 마음에 들어하며 시청자들에게 “여러분 이제 하마똥말고 독사새끼할래요?” 라며, 다음날 방송제목을 ‘독새하(독사새끼들하이)’로 정하였다. 이후로 우주하마는 '독사새끼'를 애칭(?)으로 사용중이다. 유튜브에 우주하마가 직접 쓴 고정댓글 #ㅅㅇㅇㄸㅇㅇㅆㅇㅇㄸㅇㅇ: 우주하마 본인이 코인노래방에 가서 녹음한 소찬휘 'Tears'의 하이라이 ...
